# %% [markdown]
# <a href="https://colab.research.google.com/github/ipfloater/ML_misc/blob/main/test_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ipfloater/ML_misc.git
# Out:
# fatal: destination path 'ML_misc' already exists and is not an empty directory.

# %%
import sys

sys.path = ['ML_misc/'] + sys.path

# %%
from sklearn_wrapper.utils import *

# %%
XX, yy, clf, stats0, popCaps0, binCaps0 = run_classifier_test(N=5000, p=20, p2=5, perform_cv=True, include_stacking=True, plot=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/experimental/enable_hist_gradient_boosting.py:15: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# INFO: bad rate 0.1672, wt 2.996
# INFO: pre run wt_train 2.982 wt_test 3.029
# =========================================
# Logi logisticregression
# cross_val_predict timing: 0.1399
# Logi fit timing: 0.0214
# Logi does not have feature importances
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# =========================================
# LGBM lgbmclassifier
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169262 -> initscore=-1.590866
# [LightGBM] [Info] Start training from score -1.590866
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000954 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169262 -> initscore=-1.590866
# [LightGBM] [Info] Start training from score -1.590866
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000981 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169262 -> initscore=-1.590866
# [LightGBM] [Info] Start training from score -1.590866
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000232 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169262 -> initscore=-1.590866
# [LightGBM] [Info] Start training from score -1.590866
# [LightGBM] [Info] Number of positive: 1412, number of negative: 1388
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000241 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169061 -> initscore=-1.592295
# [LightGBM] [Info] Start training from score -1.592295
# cross_val_predict timing: 1.7184
# [LightGBM] [Info] Number of positive: 1766, number of negative: 1734
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169222 -> initscore=-1.591152
# [LightGBM] [Info] Start training from score -1.591152
# LGBM fit timing: 0.4375
#    model variable  importance  rank
# 0   LGBM      V00         382     1
# 4   LGBM      V04         362     2
# 18  LGBM      V18         359     3
# 19  LGBM      V19         325     4
# 16  LGBM      V16         310     5
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# =========================================
# RandomForest randomforestclassifier
# cross_val_predict timing: 8.6138
# RandomForest fit timing: 1.9386
#            model variable  importance  rank
# 18  RandomForest      V18        0.26     1
# 0   RandomForest      V00        0.14     2
# 19  RandomForest      V19        0.10     3
# 4   RandomForest      V04        0.09     4
# 16  RandomForest      V16        0.07     5
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# =========================================
# HistGradientBoosting histgradientboostingclassifier
# cross_val_predict timing: 2.8784
# HistGradientBoosting fit timing: 0.8635
# HistGradientBoosting does not have feature importances
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# =========================================
# AdaBoosting adaboostclassifier
# cross_val_predict timing: 7.8609
# AdaBoosting fit timing: 1.7200
#           model variable  importance  rank
# 18  AdaBoosting      V18        0.17     1
# 4   AdaBoosting      V04        0.17     2
# 16  AdaBoosting      V16        0.15     3
# 0   AdaBoosting      V00        0.12     4
# 8   AdaBoosting      V08        0.11     5
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# =========================================
# Bagging baggingclassifier
# cross_val_predict timing: 3.6048
# Bagging fit timing: 1.2158
#       model variable  importance  rank
# 18  Bagging      V18        0.30     1
# 0   Bagging      V00        0.18     2
# 19  Bagging      V19        0.14     3
# 4   Bagging      V04        0.12     4
# 16  Bagging      V16        0.07     5
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# StackingClassifier
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000978 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000830 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000843 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000834 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000859 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000328 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1132
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000947 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000874 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1132
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000395 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000842 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000814 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000845 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1132
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000829 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000858 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504911 -> initscore=0.019643
# [LightGBM] [Info] Start training from score 0.019643
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000857 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000851 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1132
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Number of positive: 1412, number of negative: 1388
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001074 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504286 -> initscore=0.017143
# [LightGBM] [Info] Start training from score 0.017143
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000858 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1130, number of negative: 1110
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000833 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504464 -> initscore=0.017858
# [LightGBM] [Info] Start training from score 0.017858
# [LightGBM] [Info] Number of positive: 1129, number of negative: 1111
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000823 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504018 -> initscore=0.016072
# [LightGBM] [Info] Start training from score 0.016072
# [LightGBM] [Info] Number of positive: 1129, number of negative: 1111
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000845 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504018 -> initscore=0.016072
# [LightGBM] [Info] Start training from score 0.016072
# [LightGBM] [Info] Number of positive: 1412, number of negative: 1388
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1132
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# cross_val_predict timing: 126.5194
# [LightGBM] [Info] Number of positive: 1766, number of negative: 1734
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001312 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504571 -> initscore=0.018286
# [LightGBM] [Info] Start training from score 0.018286
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000346 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1413, number of negative: 1387
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504643 -> initscore=0.018572
# [LightGBM] [Info] Start training from score 0.018572
# [LightGBM] [Info] Number of positive: 1412, number of negative: 1388
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504286 -> initscore=0.017143
# [LightGBM] [Info] Start training from score 0.017143
# [LightGBM] [Info] Number of positive: 1766, number of negative: 1734
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1132
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# StackingClassifier fit timing: 29.5913
# StackingClassifier does not have feature importances
# pred_cv (3500, 2) wt_train (3500,) 2.982 pred0 (1500, 2) wt_test (1500,) 3.029
# INFO: post run wt_train 2.982 wt_test 3.029
# Logi cv
# Logi test
# LGBM cv
# LGBM test
# RandomForest cv
# RandomForest test
# HistGradientBoosting cv
# HistGradientBoosting test
# AdaBoosting cv
# AdaBoosting test
# Bagging cv
# Bagging test
# StackingClassifier cv
# StackingClassifier test
# Summary statistics
#                    model  type     ks  gini   auc  cap5%  cap10%  cap20%  count  wtCount
# 0                   Logi    cv  70.82  0.84  0.92   0.27    0.50    0.77   3500  10436.0
# 2                   LGBM    cv  87.83  0.96  0.98   0.30    0.58    0.92   3500  10436.0
# 4           RandomForest    cv  83.40  0.94  0.97   0.29    0.57    0.87   3500  10436.0
# 6   HistGradientBoosting    cv  87.26  0.96  0.98   0.30    0.57    0.92   3500  10436.0
# 8            AdaBoosting    cv  72.70  0.88  0.94   0.27    0.50    0.77   3500  10436.0
# 10               Bagging    cv  80.02  0.92  0.96   0.27    0.56    0.86   3500  10436.0
# 12    StackingClassifier    cv  86.50  0.96  0.98   0.29    0.56    0.91   3500  10436.0
# 1                   Logi  test  71.11  0.85  0.93   0.28    0.53    0.79   1500   4544.0
# 3                   LGBM  test  87.17  0.96  0.98   0.30    0.58    0.93   1500   4544.0
# 5           RandomForest  test  83.98  0.94  0.97   0.30    0.59    0.90   1500   4544.0
# 7   HistGradientBoosting  test  87.11  0.96  0.98   0.30    0.58    0.92   1500   4544.0
# 9            AdaBoosting  test  74.60  0.88  0.94   0.29    0.54    0.79   1500   4544.0
# 11               Bagging  test  81.24  0.92  0.96   0.28    0.57    0.87   1500   4544.0
# 13    StackingClassifier  test  87.36  0.96  0.98   0.30    0.59    0.93   1500   4544.0
# Performance by bin
#            bad_rate%
# Model    AdaBoosting Bagging HistGradientBoosting   LGBM   Logi RandomForest StackingClassifier
# Type bin
# cv   0         84.66   95.19                96.64  97.60  85.14        95.69              95.21
#      1         45.24   50.76                58.29  58.33  45.88        52.45              59.29
#      2         22.34   12.92                11.40  10.75  17.79        15.23              11.45
#      3          9.48    5.38                 1.54   1.25   5.83         3.16               1.53
#      4          5.56    2.21                 0.38   0.29   4.78         1.44               0.48
#      5          0.86    0.57                 0.29   0.38   4.72         0.19               0.38
#      6          0.48    0.38                 0.29   0.19   2.19         0.38               0.29
#      7          0.10    0.38                 0.29   0.19   2.02         0.38               0.19
#      8          0.00    1.06                 0.00   0.19   0.77         0.38               0.00
#      9          0.67    0.67                 0.19   0.10   0.19         0.10               0.48
# test 0         87.80   92.29                95.58  94.49  85.68        95.59              96.70
#      1         40.66   49.00                53.95  56.76  43.58        51.43              54.44
#      2         20.53   12.09                 9.29   8.10  14.10        10.09               8.30
#      3          7.00    5.08                 2.20   1.98   7.69         2.87               1.33
#      4          3.51    1.53                 0.66   0.44   3.30         1.10               1.10
#      5          2.65    0.66                 0.66   0.22   3.30         0.44               0.44
#      6          0.44    0.66                 0.66   0.44   2.44         0.00               0.44
#      7          0.44    0.44                 0.00   0.44   1.32         0.44               0.44
#      8          0.00    0.66                 0.00   0.00   1.32         0.66               0.00
#      9          0.22    0.66                 0.00   0.22   0.22         0.22               0.00
# run_classifier_test timing: 189.6689

# %%
res = plot_performance_curves(popCaps0, binCaps0)

# %% [markdown]
# Population Capture Curves

# %%
print(res.popCapCurves)

# %%
print(res.badCapCurves)
